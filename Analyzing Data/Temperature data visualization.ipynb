# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %% [markdown]
# 주사위 시뮬레이션

# %%
import random
print(random.randint(1,6))
# Out:
# 5

# %%
dice = []
for i in range(5) :
    dice.append(random.randint(1,6))
print(dice)
# Out:
# [2, 6, 3, 6, 1]

# %%
plt.hist(dice, bins=6)
plt.show()

# %%
dice = []
for i in range(1000000) :
    dice.append(random.randint(1,6))
plt.hist(dice, bins=6)
plt.show()

# %% [markdown]
# 기온 데이터를 히스토그램으로 표현

# %%
import csv

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
result = []

for row in data : 
    if row[-1] != '' :
        result.append(float(row[-1]))

plt.hist(result, bins=100, color='r')
plt.show()

# %%
f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
aug = []

for row in data : 
    month = row[0].split('-')
    if row[-1] != '' :
        if month[1] == '08' :
            aug.append(float(row[-1]))

plt.hist(aug, bins=100, color='r')
plt.show()

# %% [markdown]
# 1월과 8월의 데이터를 히스토그램으로 시각화하기

# %%
import csv, matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data : 
    month = row[0].split('-')
    if row[-1] != '' :
        if month[1] == '08' :
            aug.append(float(row[-1]))
        if month[1] == '01' :
            jan.append(float(row[-1]))

plt.hist(aug, bins=100, color='r', label='Aug')
plt.hist(jan, bins=100, color='b', label='Jan')
plt.legend()
plt.show()

# %% [markdown]
# 기온 데이터를 상자 그림으로 표현

# %%
result = []
for i in range(13) :
    result.append(random.randint(1, 1000))
print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [183, 389, 414, 744, 759, 798, 816, 837, 844, 850, 928, 999, 999]

# %%
f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
result = []

for row in data : 
    if row[-1] != '' :
        result.append(float(row[-1]))

plt.boxplot(result)
plt.show()

# %%
f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data : 
    month = row[0].split('-')
    if row[-1] != '' :
        if month[1] == '08' :
            aug.append(float(row[-1]))
        if month[1] == '01' :
            jan.append(float(row[-1]))

plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
plt.boxplot([aug, jan])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd830e7bdf0>,
#   <matplotlib.lines.Line2D at 0x7fd860e2cf10>,
#   <matplotlib.lines.Line2D at 0x7fd860e5f220>,
#   <matplotlib.lines.Line2D at 0x7fd860e5f850>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd860e2ca90>,
#   <matplotlib.lines.Line2D at 0x7fd860e2c820>,
#   <matplotlib.lines.Line2D at 0x7fd860e5f040>,
#   <matplotlib.lines.Line2D at 0x7fd860e5fe20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd830e7b4c0>,
#   <matplotlib.lines.Line2D at 0x7fd860e5f190>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd860e2c730>,
#   <matplotlib.lines.Line2D at 0x7fd860e5f3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd860e2cb50>,
#   <matplotlib.lines.Line2D at 0x7fd830ea1e50>],
#  'means': []}

# %% [markdown]
# 월별 기온 데이터를 상자 그림으로 표현

# %%
import csv, matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)

month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data : 
    if row[-1] != '' :
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()

# %% [markdown]
# 8월 일별 기온 데이터를 상자 그림으로 표현

# %%
import csv, matplotlib.pyplot as plt

f = open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)

day = []
for i in range(31) :
    day.append([])

for row in data : 
    if row[-1] != '' :
        if row[0].split('-')[1] == '08' :
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.boxplot(day, showfliers=False)

plt.show()
